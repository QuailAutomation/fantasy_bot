# %%
from csh_fantasy_bot.bot import ManagerBot, WS

mgr = ManagerBot()

# %%
print(f'Current week: {mgr.current_week}')
# mgr.scores()
current_week = mgr.retreive_scores(WS.current)
print(current_week)

# last 3
# last_3 = mgr.scores(WS.last(3))

# weeks3_5 = mgr.scores(WS.between(3,5))
# next
# next_week = mgr.scores(WS.next)
# Out:
# Current week: 12
# Week is: [12] (<class 'slice'>), team selector: TS.me
# Looking up for : 12
# {'4':                          G     A   +/-   PIM   SOG     FW   HIT score_type
# play_date  player_id
# 2021-04-05 7109       2.00  0.00  0.00  0.00  4.00   5.00  0.00          a
#            3788       0.00  1.00 -2.00  0.00  4.00  20.00  3.00          a
#            5363       1.00  0.00  1.00  2.00  3.00   9.00  1.00          a
#            5754       0.00  1.00  1.00  2.00  0.00   1.00  6.00          a
#            7900        NaN   NaN   NaN   NaN   NaN    NaN   NaN          a
#            4207        NaN   NaN   NaN   NaN   NaN    NaN   NaN          a
#            7124       0.00  2.00 -1.00  0.00  4.00   0.00  0.00          a
#            6005       0.00  0.00  2.00  0.00  1.00   0.00  0.00          a
#            7498       0.00  0.00  0.00  0.00  3.00   0.00  1.00          a
#            4930        NaN   NaN   NaN   NaN   NaN    NaN   NaN          a
# ...
